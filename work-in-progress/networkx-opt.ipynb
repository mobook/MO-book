# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

G = nx.erdos_renyi_graph(n, 0.2, directed=True)
nx.draw(G)

np.random.seed(10)

n = 20
x = np.random.uniform(0, 2000, n)
y = np.random.uniform(0, 1000, n)

labels = [f"c{i+1:02d}" for i in range(n)]

fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.plot(x, y, 'o', ms=10)

for i in range(n):
    d = [np.sqrt((x[i] - x[j])**2 + (y[i] - y[j])**2) for j in range(n)]
    nn = [j for j in np.argsort(d)][1:4]
    for j in nn:
        ax.plot([x[i], x[j]], [y[i], y[j]], 'r--')

# %%
erdos_renyi_graph(n, p, seed=None, directed=False)

# %%
G
