# %% [markdown]
# # A simple example of computing a real life shortest path <img align='after' width='180' src='https://drive.google.com/uc?export=view&id=19qZe5VIxkIEm7_hYkrvlH142XPBxBaEf'>
#
# ---
#  > During this course we make use of Jupyter notebooks hosted by [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
#   Notebooks deployed on `colab` require neither python nor other dependencies to be installed on your own machine, you only need a browser (preferably `chrome`) and you may also need a google account if you want to execute them.
#
# ---
#
# **Notes:**
#  1. This notebook takes some extra trouble to install some packages, due to a more modern version of `numpy` and `matplotlib` being needed than the one installed by `colab`.
#  1. From now on, we prepare our notebooks for `colab` since we assume that in case you prefer to run them locally then by know you know how and where to adapt them.

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install --upgrade numpy
    # !pip install --upgrade matplotlib

# %% [markdown]
# # Introduction
#
# Google brought with [maps]( https://www.google.com/maps) the world to our screens, including accurate geocoding and routing for several modalities.
#
# For the most, the usage of [maps]( https://www.google.com/maps) is interactive. As data and analytics professionals we often need a programmatically support for the services that [maps]( https://www.google.com/maps) offer us. Preferably free.
#
# It also offers a plethora of [development support](https://developers.google.com/), but unfortunately most is paid. That is even more so for [maps]( https://developers.google.com/maps/documentation).
#
# The same Google also offers us [colab]( https://colab.research.google.com/) and that is exactly where we are now. Colab is [free]( https://research.google.com/colaboratory/faq.html) to use, although it includes a paid [pro]( https://colab.research.google.com/signup) version.
#
# This notebook runs on the free version of colab and illustrates free packages on the [python]( https://www.python.org/) ecosystem.
#
# Alongside with free code the open source community also offers us a lot of free data and free knowledge. This notebook, and presentation, is just a skin-deep introduction.

# %% [markdown]
# ## Some heroes
# [Geoff Boeing]( https://geoffboeing.com/about/) is a true leader in demystifying urban data analytics, with a strong emphasis on street networks. His [peer reviewed publications]( https://geoffboeing.com/publications/) are open and accompanied by usable demonstrations using his own [OSMnx]( https://geoffboeing.com/2018/03/osmnx-features-roundup/) package.
# Professor [Peter Sanders]( https://algo2.iti.kit.edu/english/sanders.php), see also his [Wikipedia]( https://en.wikipedia.org/wiki/Peter_Sanders_(computer_scientist)) page, has moved his interests to other areas but his [route planning]( http://algo2.iti.kit.edu/routeplanning.php) project shaped the world of truly scalable road routing algorithms.
# From his alumni I distinguish two persons:
#  * [Dominik Schultes](http://algo2.iti.kit.edu/schultes/) who won the [DIMACS challenge on shortest paths]( http://www.diag.uniroma1.it//challenge9/data/tiger/) and made it to the [Scientific American top 50]( https://www.scientificamerican.com/article/sciam-50-the-fastest-way/). Before Dominik’s research scalable shortest paths on large national road networks where heuristics, now they are exact and can be computed at world scale.
#  * [Dennis Luxen]( http://algo2.iti.kit.edu/english/luxen.php) for creating https://github.com/Project-OSRM/osrm-backend which offers a free, scalable, implementation of [contraction hierarchies]( https://en.wikipedia.org/wiki/Contraction_hierarchies).
#
# Finally, I mention [Fletcher Foti]( https://fletcherfoti.weebly.com/) who gave us [pandana]( http://udst.github.io/pandana/).

# %%
def GetListOfInstalledPackages():
    import subprocess, sys
    reqs = subprocess.check_output([sys.executable, '-m', 'pip', 'freeze'])
    return [r.decode().split('==')[0] for r in reqs.split()]

# %%
installed_packages = GetListOfInstalledPackages()

# %% [markdown]
# Whenever we need more packages, we just install those into our session.

# %%
import sys
if "google.colab" in sys.modules:
    if 'geopandas' not in installed_packages:
        # !pip install geopandas
    if 'geopy' not in installed_packages:
        # !pip install geopy
    if 'osmnx' not in installed_packages:
        # !pip install osmnx
    if 'osmnet' not in installed_packages:
        # !pip install osmnet
    if 'pandana' not in installed_packages:
        # !pip install pandana

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install --upgrade geopy

# %% [markdown]
# ## Geocoding
#
# The world is mapped with the [geographic coordinate system](https://en.wikipedia.org/wiki/Geographic_coordinate_system) but we have difficulties remembering [latitudes]( https://en.wikipedia.org/wiki/Latitude) and [longitudes]( https://en.wikipedia.org/wiki/Longitude).
#
# We learn and remember the world better from addresses.

# %%
def FreeLocator():
    import geopy
    return geopy.Photon(user_agent='myGeocoder')

# %%
Amsterdam = FreeLocator().geocode('Amsterdam,NL')

# %% [markdown]
# # Visualization

# %%
import folium
Map = folium.Map(location=(Amsterdam.latitude,Amsterdam.longitude), zoom_start=12)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_13674820a036497ab25039c0197acc56%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_13674820a036497ab25039c0197acc56%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_13674820a036497ab25039c0197acc56%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_13674820a036497ab25039c0197acc56%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.4156045%2C%204.837025745215238%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
def Locate_geopy(description):
    location = FreeLocator().geocode(description)
    if location is not None:
        return location.latitude, location.longitude
    return None,None

# %%
import pandas as pd
pd.options.display.float_format = '{:.6f}'.format

data = {'address': [ 'Centraal Station',
                     'Amsterdam Business School',
                     'Artis',
                     'Arena',
                     'Ziggo Dome' ], 
        'color'  : [ 'blue',
                     'black',                   
                     'green',
                     'red',
                     'purple' ]}
# Create DataFrame.
df = pd.DataFrame(data)
df['city']    = 'Amsterdam'
df['country'] = 'NL'
df
# Out:
#                      address   color       city country
# 0           Centraal Station    blue  Amsterdam      NL
# 1  Amsterdam Business School   black  Amsterdam      NL
# 2                      Artis   green  Amsterdam      NL
# 3                      Arena     red  Amsterdam      NL
# 4                 Ziggo Dome  purple  Amsterdam      NL

# %%
locations = [ Locate_geopy(','.join(row[['address','city','country']])) for _, row in df.iterrows() ]
df['lat'] = [ loc[0] for loc in locations ]
df['lon'] = [ loc[1] for loc in locations ]
df
# Out:
#                      address   color       city country       lat      lon
# 0           Centraal Station    blue  Amsterdam      NL 52.378901 4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL 52.365107 4.911718
# 2                      Artis   green  Amsterdam      NL 52.415605 4.837026
# 3                      Arena     red  Amsterdam      NL 52.315990 4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL 52.313790 4.938438

# %%
for _, row in df.iterrows():
    folium.Marker((row.lat,row.lon),icon=folium.Icon(color=row.color),tooltip=row.address).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_13674820a036497ab25039c0197acc56%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_13674820a036497ab25039c0197acc56%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_13674820a036497ab25039c0197acc56%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_13674820a036497ab25039c0197acc56%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.4156045%2C%204.837025745215238%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
import osmnx as ox
import networkx as nx
from IPython.display import display

ox.config(log_console=True, use_cache=True)

# %%
# %%time 
G_walk = ox.graph_from_place('Amsterdam, NL', network_type='walk')
# Out:
# C:\Users\joaquimg\Miniconda3\lib\site-packages\osmnx\geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# CPU times: total: 51 s
# Wall time: 3min 18s

# %%
print( G_walk.number_of_nodes(), G_walk.number_of_edges() )
# Out:
# 35211 99098

# %%
df['osmnx'] = ox.distance.nearest_nodes(G_walk,df.lon,df.lat)
df
# Out:
#                      address   color       city country       lat      lon  \
# 0           Centraal Station    blue  Amsterdam      NL 52.378901 4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL 52.365107 4.911718
# 2                      Artis   green  Amsterdam      NL 52.415605 4.837026
# 3                      Arena     red  Amsterdam      NL 52.315990 4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL 52.313790 4.938438
#
#         osmnx
# 0  5629072001
# 1    46356661
# 2  8116399477
# 3  4622542635
# 4  1925143759

# %%
# %time route = nx.shortest_path(G_walk,df.iloc[0].osmnx,df.iloc[1].osmnx,weight='length')
print(route)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 17.7 ms
# [5629072001, 5629072000, 5629071975, 4239313191, 4239313081, 4239313075, 4239312638, 4239312409, 4239311933, 4239310797, 3189915006, 3175727789, 1263352467, 9283437397, 9283437392, 9283437388, 9283437390, 9283437375, 3210037368, 3185495471, 6689794785, 5919123188, 7309896051, 46411146, 3188608544, 46410382, 8238495242, 46409003, 46405684, 46402187, 5933448325, 46399571, 9407636382, 46392637, 9407636386, 7973142487, 8223730972, 1291587576, 1291587540, 46385544, 46383339, 46380741, 46379359, 46374887, 46374082, 3781170573, 7995426344, 3781170150, 3781170147, 3781170139, 2021897089, 2021897044, 7223158294, 7223158307, 2021897032, 7223210075, 7223210071, 1291468055, 3160068713, 3160068154, 46356661]

# %%
route_map = ox.plot_route_folium(G_walk, route)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f253249bb56948eb9b462797cf6dbea0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f253249bb56948eb9b462797cf6dbea0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f253249bb56948eb9b462797cf6dbea0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f253249bb56948eb9b462797cf6dbea0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.37190829354214%2C%204.907543350003587%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# %%time 
nodes = pd.DataFrame.from_dict(dict(G_walk.nodes(data=True)), orient='index')
# Out:
# CPU times: total: 93.8 ms
# Wall time: 93.8 ms

# %%
# %%time 
edges = nx.to_pandas_edgelist(G_walk)
# Out:
# C:\Users\joaquimg\Miniconda3\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# CPU times: total: 2.45 s
# Wall time: 2.51 s

# %%
nodes.street_count.describe()
# Out:
# count   35211.000000
# mean        2.816165
# std         0.996772
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# Name: street_count, dtype: float64

# %%
edges.length.describe()
# Out:
# count   99098.000000
# mean       54.205131
# std        68.289323
# min         0.130000
# 25%        15.183000
# 50%        34.610000
# 75%        68.279000
# max      1550.813000
# Name: length, dtype: float64

# %%
edges.loc[edges.length.idxmax()]
# Out:
# source                                              2632720004
# target                                              4340833704
# highway                                               tertiary
# geometry     LINESTRING (5.0484437 52.4098672, 5.0492122 52...
# est_width                                                  NaN
# access                                                     NaN
# maxspeed                                                   NaN
# junction                                                   NaN
# length                                             1550.813000
# width                                                      NaN
# oneway                                                   False
# lanes                                                      NaN
# osmid                                                  7039463
# bridge                                                     NaN
# ref                                                        NaN
# service                                                    NaN
# tunnel                                                     NaN
# area                                                       NaN
# name                                             Uitdammerdijk
# Name: 56082, dtype: object

# %%
# %time longest = nx.shortest_path(G_walk,2632720004,46544942,weight='length')
print(longest)
# Out:
# CPU times: total: 0 ns
# Wall time: 850 µs
# [2632720004, 4868500506, 46526747, 3646762450, 46515220, 7896482872, 7896482772, 7896482536, 2876000370, 2876030674, 46525998, 2875982072, 2876049179, 2876046111, 2834850861, 3380450298, 3380450325, 3380450323, 1970783754, 1970783822, 1970783783, 1970783792, 1970789262, 1970785372, 46546263, 3478950226, 2869259996, 2876043898, 46544942]

# %%
route_map = ox.plot_route_folium(G_walk, longest)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_08a1e40a0c3f422792289b4abbaeb7f3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_08a1e40a0c3f422792289b4abbaeb7f3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_08a1e40a0c3f422792289b4abbaeb7f3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_08a1e40a0c3f422792289b4abbaeb7f3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.40669741971747%2C%205.024024034527207%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# # Dijkstra on steroids for road networks

# %%
# %%time
import pandana
network = pandana.Network(nodes['x'], nodes['y'], edges['source'], edges['target'], edges[['length']],twoway=True)
# Out:
# CPU times: total: 4.36 s
# Wall time: 925 ms

# %%
network.nodes_df.head()
# Out:
#                 x         y
# 6316199  4.888396 52.370173
# 25596455 4.923563 52.364840
# 25596477 4.906097 52.367000
# 25645989 4.925075 52.365727
# 25645990 4.926110 52.366326

# %%
network.edges_df.head()
# Out:
#        from          to     length
# 0   6316199    46379627  42.497000
# 1   6316199    46389218 225.577000
# 2   6316199   391355271  62.907000
# 3  25596455  8383889398   1.791000
# 4  25596455    46356773  41.700000

# %%
df['pandana'] = network.get_node_ids(df.lon, df.lat).values
df
# Out:
#                      address   color       city country       lat      lon  \
# 0           Centraal Station    blue  Amsterdam      NL 52.378901 4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL 52.365107 4.911718
# 2                      Artis   green  Amsterdam      NL 52.415605 4.837026
# 3                      Arena     red  Amsterdam      NL 52.315990 4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL 52.313790 4.938438
#
#         osmnx     pandana
# 0  5629072001  5629071974
# 1    46356661    46356661
# 2  8116399477  8116399477
# 3  4622542635  2928936658
# 4  1925143759  4622542635

# %%
# %time path_pandana = network.shortest_path(df.iloc[2].pandana, df.iloc[3].pandana)
# Out:
# CPU times: total: 0 ns
# Wall time: 2.99 ms

# %%
# %time path_nx = nx.shortest_path(G_walk,df.iloc[2].osmnx,df.iloc[3].osmnx,weight='length')
# Out:
# CPU times: total: 250 ms
# Wall time: 260 ms

# %%
A = set(path_pandana)
B = set(path_nx)
(A | B) - (A & B)
# Out:
# {46232158,
#  46237572,
#  46240581,
#  46241169,
#  46241205,
#  46242940,
#  46245940,
#  46247806,
#  46255649,
#  46260704,
#  46264996,
#  46265577,
#  46265994,
#  46266419,
#  46267226,
#  46267229,
#  46274385,
#  46274670,
#  46275510,
#  46278192,
#  46278488,
#  46280478,
#  46280842,
#  46281209,
#  46281524,
#  46285636,
#  46291556,
#  46291719,
#  46293298,
#  46293761,
#  46295375,
#  46296981,
#  46300577,
#  46301759,
#  46301760,
#  46303077,
#  46304102,
#  46305144,
#  46305209,
#  46307985,
#  46309621,
#  46309912,
#  46311730,
#  46312415,
#  46313094,
#  46314564,
#  46314956,
#  46317329,
#  46319331,
#  46320807,
#  46321546,
#  46323267,
#  46323943,
#  46326231,
#  46326678,
#  46327739,
#  46329521,
#  46329829,
#  46331717,
#  46332009,
#  46332010,
#  46332803,
#  46332984,
#  46333825,
#  46333911,
#  46334874,
#  46335169,
#  46336020,
#  46339231,
#  93060999,
#  252728564,
#  254477712,
#  262890789,
#  295681891,
#  295681899,
#  369606077,
#  452485084,
#  497304704,
#  497304720,
#  878805275,
#  878806012,
#  878806213,
#  878808875,
#  926793900,
#  1101933078,
#  1101933080,
#  1259406528,
#  1333602328,
#  1367844148,
#  1525016908,
#  1688255243,
#  1725810217,
#  1725960722,
#  1853506943,
#  1925156931,
#  1925156934,
#  2021881776,
#  2021881798,
#  2021881804,
#  2021881810,
#  2021881821,
#  2021881826,
#  2021881841,
#  2021881843,
#  2021881847,
#  2021881848,
#  2691138239,
#  2801224787,
#  2928936658,
#  3054154668,
#  3102511138,
#  3102511139,
#  3132317673,
#  3132317679,
#  3301285116,
#  3301285117,
#  3301285121,
#  3404634823,
#  4382189126,
#  4382189139,
#  4521541048,
#  4525422041,
#  4538188789,
#  4622542635,
#  4684390284,
#  4684390320,
#  5133014954,
#  5323513026,
#  5394045965,
#  5394053135,
#  5438332847,
#  5438332850,
#  5791136663,
#  5792613349,
#  5792696880,
#  5792760520,
#  5919133211,
#  6614935661,
#  6614935668,
#  6879899205,
#  6879899216,
#  6892142909,
#  6892143052,
#  6927485798,
#  6933063414,
#  6933063422,
#  6933063429,
#  6933063433,
#  6957281887,
#  6958932853,
#  6958932854,
#  6958932858,
#  7014224677,
#  7014644569,
#  7014652994,
#  7014652995,
#  7014652996,
#  7124847108,
#  7191442434,
#  7191442439,
#  7191442440,
#  7191442442,
#  7191442444,
#  7191491356,
#  7191491357,
#  7191502893,
#  7191531889,
#  7191603158,
#  7191603163,
#  7191859086,
#  7191859087,
#  7434739098,
#  7434739102,
#  8006668209,
#  8006668210,
#  8492030537,
#  8492030539,
#  8518477129,
#  9204235876,
#  9355815528}

# %%
origs = [o for o in df.pandana for d in df.pandana]
dests = [d for o in df.pandana for d in df.pandana]
# %time distances = network.shortest_path_lengths(origs, dests)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.55 ms

# %%
n = len(df)
import numpy as np 
pd.options.display.float_format = '{:.2f}'.format
pd.DataFrame(np.array(list(distances)).reshape(n,n),index=df.address,columns=df.address)
# Out:
# address                    Centraal Station  Amsterdam Business School  \
# address
# Centraal Station                       0.00                    2241.87
# Amsterdam Business School           2241.87                       0.00
# Artis                              14851.81                   16747.56
# Arena                               6289.60                    4130.53
# Ziggo Dome                          6209.35                    4652.79
#
# address                      Artis    Arena  Ziggo Dome
# address
# Centraal Station          14851.81  6289.60     6209.35
# Amsterdam Business School 16747.56  4130.53     4652.79
# Artis                         0.00 20661.12    20259.22
# Arena                     20661.12     0.00     4133.68
# Ziggo Dome                20259.22  4133.68        0.00

# %%
np.random.seed(2021)
n = 500
sample = np.random.choice(np.array(network.nodes_df.index.values.tolist()), n, replace=False)
origs = [o for o in sample for d in sample]
dests = [d for o in sample for d in sample]

# %%
# %time distances = network.shortest_path_lengths(origs, dests)
# %time table = pd.DataFrame(np.array(list(distances)).reshape(n,n),index=sample,columns=sample)
# Out:
# CPU times: total: 5.7 s
# Wall time: 1.11 s
# CPU times: total: 172 ms
# Wall time: 25.5 ms

# %%
departure = table.max(axis=1).idxmax()
arrival = table.loc[departure].idxmax()
# %time path_pandana = network.shortest_path(departure, arrival)
# %time path_nx = nx.shortest_path(G_walk,departure,arrival,weight='length')
A = set(path_pandana)
B = set(path_nx)
(A | B) - (A & B)
# Out:
# CPU times: total: 0 ns
# Wall time: 3.99 ms
# CPU times: total: 281 ms
# Wall time: 318 ms
# set()

# %%
# %time paths = network.shortest_paths(origs,dests)
# Out:
# CPU times: total: 14 s
# Wall time: 6.09 s

# %%
sum(map(len,paths))
# Out:
# 34220326

# %%
for u,v in zip(paths[1][:-1],paths[1][1:]):
    print(G_walk.get_edge_data(u,v)[0].get('name',''))
# Out:
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Schellingwouderdijk
# Liergouw
# Liergouw
# Liergouw
#
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
# Zuiderzeeweg
#
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Zeeburgerdijk
# Panamalaan
# Panamalaan
# Cruquiuskade
# Cruquiuskade
# Cruquiuskade
# Cruquiuskade
# Cruquiuskade
# Cruquiuskade
# Oostenburgergracht
# Oostenburgergracht
# Oostenburgergracht
# ['Oesjesduiker', 'Wittenburgergracht', 'Oostenburgergracht']
# Wittenburgergracht
# Wittenburgergracht
# ['Wittenburgergracht', 'Kattenburgergracht']
# ['Kattenburgerplein', 'Kattenburgergracht']
# Kattenburgerplein
# Kattenburgerplein
#
# ['Kattenburgerplein', 'Prins Hendrikkade']
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
#
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
# Prins Hendrikkade
#
# ['Damrak', 'Prins Hendrikkade']
#
#
# Damrak
#
#
#
#
#
#
#
#
# Singel
# Droogbak
# Droogbak
# Droogbak
# Droogbak
# Droogbak
# Haarlemmer Houttuinen
# Buiten Brouwersstraat
# Buiten Brouwersstraat
# ['Haarlemmer Houttuinen', 'Nieuwe Westerdokstraat']
# Haarlemmer Houttuinen
# Haarlemmer Houttuinen
#
# Haarlemmer Houttuinen
#
# Haarlemmerplein
#
#
# Haarlemmerplein
# Haarlemmerplein
# ['Haarlemmerplein', 'Nassauplein']
# Nassauplein
# Nassauplein
# Nassauplein
# ['Haarlemmerweg', 'Nassauplein']
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Haarlemmerweg
# Kimpoweg
# Fornebukade
#
# Kimpoweg
# Kimpoweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Arlandaweg
# Barajasweg
# Barajasweg
# Barajasweg
# ['Naritaweg', 'Barajasweg']
# Naritaweg
# Naritaweg
# Naritaweg
# Naritaweg
# Naritaweg
# Naritaweg
# Naritaweg
#
# Seineweg
# Theemsweg
# Theemsweg
#
# Sierenborch
# Sierenborch
# Sierenborch
# Sierenborch
# Roesiel
# Diepen
#
#
#
# Luvernes
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Westpoortweg
# Ruijgoordweg
# Ruijgoordweg
#
# Oceanenweg
# Oceanenweg
# Oceanenweg
# Oceanenweg
# Oceanenweg
# Cacaoweg
# Cacaoweg
# Cacaoweg
# Cacaoweg

# %%
route_map = ox.plot_route_folium(G_walk, paths[1],color='red',map=Map)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e35d5b26c3034aa4a1ff4b057153b0e0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e35d5b26c3034aa4a1ff4b057153b0e0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e35d5b26c3034aa4a1ff4b057153b0e0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e35d5b26c3034aa4a1ff4b057153b0e0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.384461673071065%2C%204.868491563297187%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...
