# %% [markdown]
# ```{index} single: application; shortest path
# ```
# ```{index} networkx
# ```
# ```{index} network optimization
# ```
# ```{index} pandas dataframe
# ```
#
# # Extra material: Shortest path in real life

# %%
import subprocess
import sys

class ColabInstaller():

    def __init__(self):
        reqs = subprocess.check_output([sys.executable, '-m', 'pip', 'freeze'])
        self.installed_packages = [r.decode().split('==')[0] for r in reqs.split()]

    def on_colab(self):
        return "google.colab" in sys.modules

    def install(self, package):
        if self.on_colab():
            subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package])
            self.installed_packages.append(package)

    def upgrade(self, package):
        if self.on_colab():
            subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", package])

colab = ColabInstaller()
colab.upgrade('numpy')
colab.upgrade('matplotlib')
colab.install('geopandas')
colab.install('geopy')
colab.install('osmnx')
colab.install('osmnet')
colab.install('pandana')
colab.upgrade('geopy')

# %% [markdown]
# # Introduction
#
# Google brought with [maps]( https://www.google.com/maps) the world to our screens, including accurate geocoding and routing for several modalities. For the most, the usage of [maps]( https://www.google.com/maps) is interactive. As data and analytics professionals we often need a programmatically support for the services that [maps]( https://www.google.com/maps) offer us, preferably free. It also offers a plethora of [development support](https://developers.google.com/), but unfortunately most is paid. That is even more so for [maps]( https://developers.google.com/maps/documentation).

# %% [markdown]
# ## Some background information and history
# [Geoff Boeing]( https://geoffboeing.com/about/) is a true leader in demystifying urban data analytics, with a strong emphasis on street networks. His [peer reviewed publications]( https://geoffboeing.com/publications/) are open and accompanied by usable demonstrations using his own [OSMnx]( https://geoffboeing.com/2018/03/osmnx-features-roundup/) package.
# Professor [Peter Sanders]( https://algo2.iti.kit.edu/english/sanders.php), see also his [Wikipedia]( https://en.wikipedia.org/wiki/Peter_Sanders_(computer_scientist)) page, has moved his interests to other areas but his [route planning]( http://algo2.iti.kit.edu/routeplanning.php) project shaped the world of truly scalable road routing algorithms.
# From his alumni I distinguish two persons:
#  * [Dominik Schultes](http://algo2.iti.kit.edu/schultes/) who won the [DIMACS challenge on shortest paths]( http://www.diag.uniroma1.it//challenge9/data/tiger/) and made it to the [Scientific American top 50]( https://www.scientificamerican.com/article/sciam-50-the-fastest-way/). Before Dominik’s research scalable shortest paths on large national road networks where heuristics, now they are exact and can be computed at world scale.
#  * [Dennis Luxen]( http://algo2.iti.kit.edu/english/luxen.php) for creating https://github.com/Project-OSRM/osrm-backend which offers a free, scalable, implementation of [contraction hierarchies]( https://en.wikipedia.org/wiki/Contraction_hierarchies).
#
# Finally, I mention [Fletcher Foti]( https://fletcherfoti.weebly.com/) who gave us [pandana]( http://udst.github.io/pandana/).

# %% [markdown]
# ## Geocoding
#
# The world is mapped with the [geographic coordinate system](https://en.wikipedia.org/wiki/Geographic_coordinate_system) but we have difficulties remembering [latitudes]( https://en.wikipedia.org/wiki/Latitude) and [longitudes]( https://en.wikipedia.org/wiki/Longitude).
#
# We learn and remember the world better from addresses.

# %%
import geopy
    
def FreeLocator():
    return geopy.Photon(user_agent='myGeocoder')

Amsterdam = FreeLocator().geocode('Amsterdam,NL')

# %% [markdown]
# # Visualization

# %%
import folium
Map = folium.Map(location=(Amsterdam.latitude,Amsterdam.longitude), zoom_start=12)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a48f94a2737b563a08cdf5021ed7cf5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a48f94a2737b563a08cdf5021ed7cf5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a48f94a2737b563a08cdf5021ed7cf5a = L.map(
#                 &quot;map_a48f94a2737b563a08cdf5021ed7cf5a&quot;,
#                 {
#                     center: [51.4940044, -0.0068219],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0446854971876da390465f73090fd7fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def locate_geopy(description):
    location = FreeLocator().geocode(description)
    if location is not None:
        return location.latitude, location.longitude
    return None, None

# %%
import pandas as pd
pd.options.display.float_format = '{:.6f}'.format

data = {'address': [ 'Centraal Station',
                     'Amsterdam Business School',
                     'Artis',
                     'Arena',
                     'Ziggo Dome' ], 
        'color'  : [ 'blue',
                     'black',                   
                     'green',
                     'red',
                     'purple' ]}
# Create DataFrame.
df = pd.DataFrame(data)
df['city']    = 'Amsterdam'
df['country'] = 'NL'
df
# Out:
#                      address   color       city country
# 0           Centraal Station    blue  Amsterdam      NL
# 1  Amsterdam Business School   black  Amsterdam      NL
# 2                      Artis   green  Amsterdam      NL
# 3                      Arena     red  Amsterdam      NL
# 4                 Ziggo Dome  purple  Amsterdam      NL

# %%
locations = [ locate_geopy(','.join(row[['address','city','country']])) for _, row in df.iterrows() ]
df['lat'] = [ loc[0] for loc in locations ]
df['lon'] = [ loc[1] for loc in locations ]
df
# Out:
#                      address   color       city country        lat        lon
# 0           Centraal Station    blue  Amsterdam      NL  52.378901   4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL  52.365107   4.911718
# 2                      Artis   green  Amsterdam      NL -30.401207 -56.481521
# 3                      Arena     red  Amsterdam      NL  52.315990   4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL  52.313629   4.938207

# %%
for _, row in df.iterrows():
    folium.Marker((row.lat,row.lon),icon=folium.Icon(color=row.color), tooltip=row.address).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a48f94a2737b563a08cdf5021ed7cf5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a48f94a2737b563a08cdf5021ed7cf5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a48f94a2737b563a08cdf5021ed7cf5a = L.map(
#                 &quot;map_a48f94a2737b563a08cdf5021ed7cf5a&quot;,
#                 {
#                     center: [51.4940044, -0.0068219],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0446854971876da390465f73090fd7fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var marker_4ba5ee36eaaa5c18ec261d9c0554b044 = L.marker(
#                 [52.378901, 4.9005805],
#                 {}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var icon_3c0d233f3f407414368656b6ef7d9315 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ba5ee36eaaa5c18ec261d9c0554b044.setIcon(icon_3c0d233f3f407414368656b6ef7d9315);
#
#
#             marker_4ba5ee36eaaa5c18ec261d9c0554b044.bindTooltip(
#                 `&lt;div&gt;
#                      Centraal Station
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3385c536e9b6881951bcabfe48f11dd = L.marker(
#                 [52.3651074, 4.9117176],
#                 {}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var icon_044b80af84090a543129c3cea852ebc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3385c536e9b6881951bcabfe48f11dd.setIcon(icon_044b80af84090a543129c3cea852ebc1);
#
#
#             marker_c3385c536e9b6881951bcabfe48f11dd.bindTooltip(
#                 `&lt;div&gt;
#                      Amsterdam Business School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7365a0a4c41fd638a52ec7262055d2de = L.marker(
#                 [-30.4012065, -56.4815211],
#                 {}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var icon_ef4f70ea3db5ca6ed1b1f7360bc6a3ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7365a0a4c41fd638a52ec7262055d2de.setIcon(icon_ef4f70ea3db5ca6ed1b1f7360bc6a3ac);
#
#
#             marker_7365a0a4c41fd638a52ec7262055d2de.bindTooltip(
#                 `&lt;div&gt;
#                      Artis
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_42814c6b2ad95ec788ff4af53460faad = L.marker(
#                 [52.3159898, 4.9429305],
#                 {}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var icon_1b5861c558f46a104e9a438761b3a49f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_42814c6b2ad95ec788ff4af53460faad.setIcon(icon_1b5861c558f46a104e9a438761b3a49f);
#
#
#             marker_42814c6b2ad95ec788ff4af53460faad.bindTooltip(
#                 `&lt;div&gt;
#                      Arena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_56023f5784dfdaeaa76dde681ec36d5a = L.marker(
#                 [52.31362925, 4.938206841509185],
#                 {}
#             ).addTo(map_a48f94a2737b563a08cdf5021ed7cf5a);
#
#
#             var icon_df8df656fcd502f232bace82c457ef4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_56023f5784dfdaeaa76dde681ec36d5a.setIcon(icon_df8df656fcd502f232bace82c457ef4e);
#
#
#             marker_56023f5784dfdaeaa76dde681e

# %%
import osmnx as ox
import networkx as nx
from IPython.display import display

ox.config(log_console=True, use_cache=True)
# Out:
# /Users/ale/.pyenv/versions/3.10.6/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
# %%time 
G_walk = ox.graph_from_place('Amsterdam, NL', network_type='walk')
# Out:
# CPU times: user 1min, sys: 1.12 s, total: 1min 1s
# Wall time: 1min 2s

# %%
print( G_walk.number_of_nodes(), G_walk.number_of_edges() )
# Out:
# 37079 104568

# %%
df['osmnx'] = ox.distance.nearest_nodes(G_walk,df.lon,df.lat)
df
# Out:
#                      address   color       city country        lat        lon  \
# 0           Centraal Station    blue  Amsterdam      NL  52.378901   4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL  52.365107   4.911718
# 2                      Artis   green  Amsterdam      NL -30.401207 -56.481521
# 3                      Arena     red  Amsterdam      NL  52.315990   4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL  52.313629   4.938207
#
#         osmnx
# 0  5629072001
# 1    46356661
# 2  1768194163
# 3  4622542635
# 4  1925143759

# %%
# %time route = nx.shortest_path(G_walk,df.iloc[0].osmnx,df.iloc[1].osmnx,weight='length')
print(route)
# Out:
# CPU times: user 29.3 ms, sys: 4.09 ms, total: 33.3 ms
# Wall time: 33.7 ms
# [5629072001, 5629072000, 5629071975, 4239313191, 4239313081, 4239313075, 4239312638, 4239312409, 9683540350, 4239311933, 4239310797, 3189915006, 3175727789, 1263352467, 9807404628, 9959600367, 9283437392, 9982135036, 9982135039, 9982135032, 9982135049, 9982118415, 9971788071, 9807403578, 46411146, 46410382, 8238495242, 46409003, 46405684, 46402187, 5933448325, 4959039686, 9407636386, 1291587477, 9913510572, 8223730972, 1291587576, 8223730971, 8223752620, 46383339, 46380741, 46379359, 46374887, 46374082, 3781170573, 7995426344, 3781170150, 3781170147, 3781170139, 2021897089, 2021897044, 7223158294, 7223158307, 2021897032, 7223210075, 7223210071, 1291468055, 3160068713, 3160068154, 46356661]

# %%
route_map = ox.plot_route_folium(G_walk, route)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3a4d20a8d5b8bfe34b4af1b21370073 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3a4d20a8d5b8bfe34b4af1b21370073&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e3a4d20a8d5b8bfe34b4af1b21370073 = L.map(
#                 &quot;map_e3a4d20a8d5b8bfe34b4af1b21370073&quot;,
#                 {
#                     center: [52.3718573306941, 4.907596117370764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28082f8e576280f31e4da432688849cb = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_27e5326c7c25d54ff0c9c3d1237d9872 = L.polyline(
#                 [[52.378908, 4.9005558], [52.3788886, 4.9005366]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_35c9299287c85f5026cc4ff2b64fe3cb = L.polyline(
#                 [[52.3788886, 4.9005366], [52.3788842, 4.9005322]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_6cc7d4627f6fb1f177382ba7175741b6 = L.polyline(
#                 [[52.3788842, 4.9005322], [52.3788759, 4.900524], [52.3788645, 4.9005127], [52.3787763, 4.9004253], [52.3787537, 4.9004028]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_ada43bb7e4e72ced99cfc0500c6363e8 = L.polyline(
#                 [[52.3787537, 4.9004028], [52.3787464, 4.9003956]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_b1540aa4018ad908a07deff76db737a8 = L.polyline(
#                 [[52.3787464, 4.9003956], [52.3787393, 4.9003887]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3a4d20a8d5b8bfe34b4af1b21370073);
#
#
#             var poly_line_723b404dfdfd4d9d14d0c23d9a8b453c = L.polyline(
#                 [[52.3787393, 4.9003887], [52.3787178, 4.900368], [52.3786285, 4.9002817], [52.3785828, 4.9002376], [52.3785705, 4.9002257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %%
# %%time 
nodes = pd.DataFrame.from_dict(dict(G_walk.nodes(data=True)), orient='index')
# Out:
# CPU times: user 144 ms, sys: 14 ms, total: 158 ms
# Wall time: 203 ms

# %%
# %%time 
edges = nx.to_pandas_edgelist(G_walk)
# Out:
# /Users/ale/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# CPU times: user 4.16 s, sys: 55.8 ms, total: 4.22 s
# Wall time: 4.25 s

# %%
nodes.street_count.describe()
# Out:
# count   37079.000000
# mean        2.821840
# std         0.994714
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         7.000000
# Name: street_count, dtype: float64

# %%
edges.length.describe()
# Out:
# count   104568.000000
# mean        52.067069
# std         66.243924
# min          0.048000
# 25%         14.511750
# 50%         32.674000
# 75%         65.676500
# max       1550.813000
# Name: length, dtype: float64

# %%
edges.loc[edges.length.idxmax()]
# Out:
# source                                              2632720004
# target                                              4340833704
# width                                                      NaN
# service                                                    NaN
# junction                                                   NaN
# est_width                                                  NaN
# ref                                                        NaN
# highway                                               tertiary
# maxspeed                                                   NaN
# tunnel                                                     NaN
# geometry     LINESTRING (5.0484437 52.4098672, 5.0492122 52...
# area                                                       NaN
# bridge                                                     NaN
# osmid                                                  7039463
# length                                             1550.813000
# name                                             Uitdammerdijk
# access                                                     NaN
# reversed                                                 False
# oneway                                                   False
# lanes                                                      NaN
# Name: 56277, dtype: object

# %%
# %time longest = nx.shortest_path(G_walk,2632720004,46544942,weight='length')
print(longest)
# Out:
# CPU times: user 1.71 ms, sys: 70 µs, total: 1.78 ms
# Wall time: 2.61 ms
# [2632720004, 4868500506, 46526747, 3646762450, 46515220, 7896482872, 7896482772, 7896482536, 2876000370, 2876030674, 46525998, 2875982072, 2876049179, 2876046111, 2834850861, 3380450298, 3380450325, 3380450323, 1970783754, 1970783822, 1970783783, 1970783792, 1970789262, 1970785372, 46546263, 3478950226, 2869259996, 2876043898, 46544942]

# %%
route_map = ox.plot_route_folium(G_walk, longest)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2ea7b3e31b4fc22f645bbcc0af7a3d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2ea7b3e31b4fc22f645bbcc0af7a3d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a2ea7b3e31b4fc22f645bbcc0af7a3d9 = L.map(
#                 &quot;map_a2ea7b3e31b4fc22f645bbcc0af7a3d9&quot;,
#                 {
#                     center: [52.40669741971747, 5.024024034527207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7cb0360da345f274f06a527fafbef8e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a2ea7b3e31b4fc22f645bbcc0af7a3d9);
#
#
#             var poly_line_e736b7a8a56d6afbc27973fd3cc4e0ea = L.polyline(
#                 [[52.4098672, 5.0484437], [52.4094882, 5.0481011], [52.4092278, 5.0478833], [52.4089609, 5.0476735]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2ea7b3e31b4fc22f645bbcc0af7a3d9);
#
#
#             var poly_line_de2a3425834642e3e14f7116c94fd043 = L.polyline(
#                 [[52.4089609, 5.0476735], [52.4084633, 5.0472729], [52.4077928, 5.0467457], [52.4073764, 5.0464191], [52.4071597, 5.0462581], [52.4070967, 5.0462022]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2ea7b3e31b4fc22f645bbcc0af7a3d9);
#
#
#             var poly_line_11ed15550e47f9980c86f8aaecaa0800 = L.polyline(
#                 [[52.4070967, 5.0462022], [52.4070129, 5.046098], [52.4069722, 5.0460328], [52.4069366, 5.0459639], [52.406901, 5.0458719], [52.4068564, 5.0456985]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2ea7b3e31b4fc22f645bbcc0af7a3d9);
#
#
#             var poly_line_5b1f9adb8a589d66a941905b4d3cd371 = L.polyline(
#                 [[52.4068564, 5.0456985], [52.4068369, 5.045587], [52.4064108, 5.043865], [52.4063374, 5.0434715], [52.4062865, 5.0431458], [52.4062256, 5.0427761], [52.4061617, 5.0425162], [52.406057, 5.0423144], [52.4055508, 5.0413756], [52.4054664, 5.041119], [52.4053913, 5.0407697], [52.4052348, 5.0391158], [52.4051613, 5.0386472], [52.4050613, 5.0382672], [52.4049891, 5.0380887], [52.4048454, 5.0378191], [52.404394, 5.0372309], [52.4041258, 5.0368865], [52.4039098, 5.0366198], [52.4037223, 5.0363717], [52.4036203, 5.0362253], [52.4035325, 5.0360648], [52.4034655, 5.0359291]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2ea7b3e31b4fc22f645bbcc0af7a3d9);
#
#
#             var poly_line_301ca71e6809517dbedf44a8bb658e27 = L.polyline(
#                 [[52.4034655, 5.0359291], [52.403497, 5.0358817], [52.4035335, 5.0358516], [52.403578, 5.035828], [52.4036686, 5.0357962]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false,

# %% [markdown]
# # Dijkstra on steroids for road networks

# %%
# %%time
import pandana
network = pandana.Network(nodes['x'], nodes['y'], edges['source'], edges['target'], edges[['length']],twoway=True)
# Out:
# CPU times: user 2.75 s, sys: 44.6 ms, total: 2.8 s
# Wall time: 2.98 s

# %%
network.nodes_df.head()
# Out:
#                 x         y
# 6316199  4.888396 52.370173
# 25596455 4.923563 52.364840
# 25596477 4.906097 52.367000
# 25645989 4.925075 52.365727
# 25658579 4.930438 52.364544

# %%
network.edges_df.head()
# Out:
#        from          to     length
# 0   6316199    46379627  42.497000
# 1   6316199    46389218 225.577000
# 2   6316199   391355271  62.907000
# 3  25596455  8383889398   1.791000
# 4  25596455    46356773  41.700000

# %%
df['pandana'] = network.get_node_ids(df.lon, df.lat).values
df
# Out:
#                      address   color       city country        lat        lon  \
# 0           Centraal Station    blue  Amsterdam      NL  52.378901   4.900581
# 1  Amsterdam Business School   black  Amsterdam      NL  52.365107   4.911718
# 2                      Artis   green  Amsterdam      NL -30.401207 -56.481521
# 3                      Arena     red  Amsterdam      NL  52.315990   4.942931
# 4                 Ziggo Dome  purple  Amsterdam      NL  52.313629   4.938207
#
#         osmnx     pandana
# 0  5629072001  5629071974
# 1    46356661    46356661
# 2  1768194163  1768194163
# 3  4622542635  2928936658
# 4  1925143759  4622542635

# %%
# %time path_pandana = network.shortest_path(df.iloc[2].pandana, df.iloc[3].pandana)
# Out:
# CPU times: user 10.6 ms, sys: 5.56 ms, total: 16.1 ms
# Wall time: 15.3 ms

# %%
# %time path_nx = nx.shortest_path(G_walk,df.iloc[2].osmnx,df.iloc[3].osmnx,weight='length')
# Out:
# CPU times: user 268 ms, sys: 17.9 ms, total: 286 ms
# Wall time: 291 ms

# %%
A = set(path_pandana)
B = set(path_nx)
(A | B) - (A & B)
# Out:
# {46232158,
#  46237572,
#  46240581,
#  46241169,
#  46241205,
#  46242937,
#  46242940,
#  46245940,
#  46247806,
#  46255649,
#  46260704,
#  46264996,
#  46265577,
#  46265994,
#  46266419,
#  46267226,
#  46267229,
#  46274385,
#  46274670,
#  46275359,
#  46275510,
#  46278192,
#  46278488,
#  46280478,
#  46280842,
#  46281091,
#  46281209,
#  46281430,
#  46281524,
#  46281920,
#  46283239,
#  46283971,
#  46284393,
#  46284949,
#  46285251,
#  46285451,
#  46288061,
#  46291556,
#  254477712,
#  262890789,
#  497304704,
#  497304720,
#  878805275,
#  878806012,
#  878806213,
#  878808875,
#  1101933078,
#  1259406528,
#  1545015322,
#  1548111106,
#  1688255243,
#  1725810217,
#  1725960722,
#  1925156931,
#  1925156934,
#  2801224787,
#  2928936658,
#  3132312675,
#  4382189126,
#  4382189139,
#  4538188789,
#  4622542635,
#  4684390284,
#  4684390320,
#  5133014954,
#  5323513026,
#  5394045965,
#  5394053135,
#  5438332847,
#  5438332850,
#  6614935661,
#  6653983649,
#  6654004829,
#  6879899205,
#  6879899216,
#  6892142909,
#  6892143052,
#  6958932853,
#  6958932854,
#  6958932858,
#  7124847108,
#  7434739098,
#  7434739102,
#  8492030537,
#  8492030539,
#  8506404118,
#  8518477120,
#  8518477127,
#  9355815528,
#  9708635342}

# %%
origs = [o for o in df.pandana for d in df.pandana]
dests = [d for o in df.pandana for d in df.pandana]
# %time distances = network.shortest_path_lengths(origs, dests)
# Out:
# CPU times: user 14.1 ms, sys: 3.95 ms, total: 18 ms
# Wall time: 16.7 ms

# %%
import numpy as np 

n = len(df)
pd.options.display.float_format = '{:.2f}'.format
pd.DataFrame(np.array(list(distances)).reshape(n,n),index=df.address,columns=df.address)
# Out:
# address                    Centraal Station  Amsterdam Business School  \
# address
# Centraal Station                       0.00                    2218.20
# Amsterdam Business School           2218.20                       0.00
# Artis                              11501.29                   11825.68
# Arena                               6274.28                    4130.58
# Ziggo Dome                          6084.35                    4537.02
#
# address                      Artis    Arena  Ziggo Dome
# address
# Centraal Station          11501.29  6274.28     6084.35
# Amsterdam Business School 11825.68  4130.58     4537.02
# Artis                         0.00 14651.95    13954.61
# Arena                     14651.95     0.00     4127.14
# Ziggo Dome                13954.61  4127.14        0.00

# %%
np.random.seed(2021)
n = 500
sample = np.random.choice(np.array(network.nodes_df.index.values.tolist()), n, replace=False)
origs = [o for o in sample for d in sample]
dests = [d for o in sample for d in sample]

# %%
# %time distances = network.shortest_path_lengths(origs, dests)
# %time table = pd.DataFrame(np.array(list(distances)).reshape(n,n),index=sample,columns=sample)
# Out:
# CPU times: user 5.23 s, sys: 65.9 ms, total: 5.3 s
# Wall time: 5.33 s
# CPU times: user 21.1 ms, sys: 297 µs, total: 21.4 ms
# Wall time: 21.5 ms

# %%
departure = table.max(axis=1).idxmax()
arrival = table.loc[departure].idxmax()
# %time path_pandana = network.shortest_path(departure, arrival)
# %time path_nx = nx.shortest_path(G_walk,departure,arrival,weight='length')
A = set(path_pandana)
B = set(path_nx)
(A | B) - (A & B)
# Out:
# CPU times: user 4.6 ms, sys: 3.47 ms, total: 8.07 ms
# Wall time: 7.24 ms
# CPU times: user 594 ms, sys: 17.1 ms, total: 611 ms
# Wall time: 617 ms
# set()

# %%
# %time paths = network.shortest_paths(origs,dests)
# Out:
# CPU times: user 12.9 s, sys: 549 ms, total: 13.5 s
# Wall time: 13.5 s

# %%
sum(map(len,paths))
# Out:
# 35377572

# %%
for u,v in zip(paths[1][:-1],paths[1][1:]):
    print(G_walk.get_edge_data(u,v)[0].get('name',''))
# Out:
# Oostoever
#
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
#
#
#
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Jan Evertsenstraat
# Orteliuskade
# Orteliuskade
# Orteliuskade
# Van Middellandtstraat
# Orteliusstraat
# Postjesweg
# Van Spilbergenstraat
# Postjesweg
#
#
#
#
# Hoofdweg
# Hoofdweg
# Hoofdweg
# Hoofdweg
# Hoofdweg
# Hoofdweg
# Surinameplein
# Surinameplein
# Surinamestraat
# Surinamestraat
# Surinamestraat
# ['Surinamestraat', 'Overtoom']
# Overtoom
#
# Overtoom
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
#
#
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Amstelveenseweg
# Laan der Hesperiden
#
#
#
# Stadionplein
# Laan der Hesperiden
# Laan der Hesperiden
# Laan der Hesperiden
# Olympisch Stadion
# Olympisch Stadion
# Olympisch Stadion
#
# Na Druk Gelukbrug
#
#
# Burgerweeshuispad

# %%
route_map = ox.plot_route_folium(G_walk, paths[1],color='red',map=Map)
display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59ec387f034476260039ef2952a1f85d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59ec387f034476260039ef2952a1f85d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_59ec387f034476260039ef2952a1f85d = L.map(
#                 &quot;map_59ec387f034476260039ef2952a1f85d&quot;,
#                 {
#                     center: [52.35997775604485, 4.848116886402437],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2eb28c7116a7517545764bbb3ae9f1d7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_fdb5fc8edc78bc8bd36f9e18dcdde428 = L.polyline(
#                 [[52.3724094, 4.8270483], [52.3722881, 4.827216]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_9e0d055decdddfac1657c9c47ea754d8 = L.polyline(
#                 [[52.3722881, 4.827216], [52.3722225, 4.8273007], [52.3718933, 4.8277755]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_f83e90f93acb77d10db341798d90fc90 = L.polyline(
#                 [[52.3718933, 4.8277755], [52.3715426, 4.8282585]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_c7c766692a860b7aff26fe44630665b2 = L.polyline(
#                 [[52.3715426, 4.8282585], [52.3706192, 4.8295431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_d29be9cf0484a95059822e73347e366d = L.polyline(
#                 [[52.3706192, 4.8295431], [52.3705892, 4.8295746], [52.3703027, 4.8299628], [52.3702896, 4.8301323], [52.3702955, 4.8303465]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59ec387f034476260039ef2952a1f85d);
#
#
#             var poly_line_7c9e80dde1d11656a016d5c1b8712cec = L.polyline(
#                 [[52.3702955, 4.8303465], [52.3702817, 4.8304792], [52.3702417, 4.8306329]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quo
